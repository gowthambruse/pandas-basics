# %% [markdown]
# # pandas

# %%
import pandas as pd
orders = pd.read_table('http://bit.ly/chiporders')

# %%
user_cols = ["sno","age","gender","name","regno"]
users = pd.read_table('http://bit.ly/movieusers' ,sep= '|', header = None, names = user_cols )
users.head()
# Out:
#    sno  age gender        name  regno
# 0    1   24      M  technician  85711
# 1    2   53      F       other  94043
# 2    3   23      M      writer  32067
# 3    4   24      M  technician  43537
# 4    5   33      F       other  15213

# %%
ufo = pd.read_table('http://bit.ly/uforeports' , sep = ',')
ufo.tail()
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
type(ufo['City'])
# Out:
# pandas.core.series.Series

# %%
ufo['Location'] = ufo['City'] + " --> " + ufo['State']

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                       Location
# 0                Ithaca --> NY
# 1           Willingboro --> NJ
# 2               Holyoke --> CO
# 3               Abilene --> KS
# 4  New York Worlds Fair --> NY

# %%
movies = pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.shape
# Out:
# (979, 6)

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
movies.describe(include = ['object'])
# Out:
#                                   title content_rating  genre  \
# count                               979            976    979
# unique                              975             12     16
# top     The Girl with the Dragon Tattoo              R  Drama
# freq                                  2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
movies.columns
# Out:
# Index([u'star_rating', u'title', u'content_rating', u'genre', u'duration',
#        u'actors_list'],
#       dtype='object')

# %%
movies.rename(columns ={'genre':'sex'},inplace='True')

# %%
movies.columns
# Out:
# Index([u'star_rating', u'title', u'content_rating', u'sex', u'duration',
#        u'actors_list'],
#       dtype='object')

# %%
movies[movies.star_rating > 9.2]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
movies[(movies.star_rating > 8) & (movies.genre == 'Crime')].head()
# Out:
#     star_rating                     title content_rating  genre  duration  \
# 0           9.3  The Shawshank Redemption              R  Crime       142
# 1           9.2             The Godfather              R  Crime       175
# 2           9.1    The Godfather: Part II              R  Crime       200
# 4           8.9              Pulp Fiction              R  Crime       154
# 21          8.7               City of God              R  Crime       130
#
#                                           actors_list  \
# 0   [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1     [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4   [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 21  [u'Alexandre Rodrigues', u'Matheus Nachtergael...
#
#                                  wel
# 0   Crime-->The Shawshank Redemption
# 1              Crime-->The Godfather
# 2     Crime-->The Godfather: Part II
# 4               Crime-->Pulp Fiction
# ...

# %%
movies.star_rating.tail()
# Out:
# 974    7.4
# 975    7.4
# 976    7.4
# 977    7.4
# 978    7.4
# Name: star_rating, dtype: float64

# %%
for ti in movies.title:
    print ti
# Out:
# The Shawshank Redemption
# The Godfather
# The Godfather: Part II
# The Dark Knight
# Pulp Fiction
# 12 Angry Men
# The Good, the Bad and the Ugly
# The Lord of the Rings: The Return of the King
# Schindler's List
# Fight Club
# The Lord of the Rings: The Fellowship of the Ring
# Inception
# Star Wars: Episode V - The Empire Strikes Back
# Forrest Gump
# The Lord of the Rings: The Two Towers
# Interstellar
# One Flew Over the Cuckoo's Nest
# Seven Samurai
# Goodfellas
# Star Wars
# The Matrix
# City of God
# It's a Wonderful Life
# The Usual Suspects
# Se7en
# Life Is Beautiful
# Once Upon a Time in the West
# The Silence of the Lambs
# Leon: The Professional
# City Lights
# Spirited Away
# The Intouchables
# Casablanca
# Whiplash
# American History X
# Modern Times
# Saving Private Ryan
# Raiders of the Lost Ark
# Rear Window
# Psycho
# The Green Mile
# Sunset Blvd.
# The Pianist
# The Dark Knight Rises
# Gladiator
# Terminator 2: Judgment Day
# Memento
# Taare Zameen Par
# ...

# %% [markdown]
# ## XLS to CSV using pandas

# %%
import pandas as pd
import json
Excel = pd.read_excel('/home/whirldata-gowtham/WHIZ.AI/Default-Summary-20170908.xls', sheetname='Call Data')
Excel.to_csv('Output.csv', encoding='utf-8', index=False,sep=",")
csv_file = pd.read_csv('Output.csv',sep=",")
csv_file.head()
# Out:
#          Caller      Receiver       Call Start Time Call Direction  \
# 0  12019781316N  18004742147N  2017-09-05T17:10:58Z             in
# 1  12027518806N  18004742147N  2017-09-05T18:28:47Z             in
# 2  12039180749N  18004742147N  2017-09-07T15:32:49Z             in
# 3  12058222835N  18004742147N  2017-09-02T10:42:42Z             in
# 4  12063635090N  18004742147N  2017-09-05T15:24:40Z             in
#
#                        User Queue Name  Call Duration    Call Result  \
# 0           Alice Bolognini  Honeywell            660   Call Succeed
# 1  Voicemail Only Honeywell  Honeywell             18  Not Connected
# 2              Lorena Lemos  Honeywell            306   Call Succeed
# 3  Voicemail Only Honeywell  Honeywell             18  Not Connected
# 4           Carlo Bolognini  Honeywell            186   Call Succeed
#
#                  City State
# 0          JerseyCity    NJ
# 1  DistrictofColumbia    DC
# 2          Bridgeport    CT
# 3          Birmingham    AL
# ...

# %%
movies['genre'].isnull().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: genre, dtype: bool

# %%
counts = movies['genre'].value_counts()
counts
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=979, step=1)

# %%
movies.shape
# Out:
# (979, 7)

# %%
movies.describe
# Out:
# <bound method DataFrame.describe of      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# ...

# %%
cols = movies.columns
for i in range (0,len(cols)):
    print cols[i]
# Out:
# star_rating
# title
# content_rating
# genre
# duration
# actors_list
# wel

# %%
movies.index
movies.loc [0,'title']
movies.set_index('title', inplace = True)
movies.head()
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
#
#                                                                 actors_list  \
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# Pulp Fiction              [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
#                                                        wel
# ...

# %%
movies.loc['The Shawshank Redemption','star_rating']
# Out:
# 9.3000000000000007

# %%
movies.groupby
# Out:
# <bound method DataFrame.groupby of                                                    star_rating content_rating  \
# title
# The Shawshank Redemption                                   9.3              R
# The Godfather                                              9.2              R
# The Godfather: Part II                                     9.1              R
# The Dark Knight                                            9.0          PG-13
# Pulp Fiction                                               8.9              R
# 12 Angry Men                                               8.9      NOT RATED
# The Good, the Bad and the Ugly                             8.9      NOT RATED
# The Lord of the Rings: The Return of the King              8.9          PG-13
# Schindler's List                                           8.9              R
# Fight Club                                                 8.9              R
# ...

# %%
movies.genre.value_counts().sort_values()
# Out:
# Fantasy        1
# History        1
# Family         2
# Film-Noir      3
# Thriller       5
# Sci-Fi         5
# Western        9
# Mystery       16
# Horror        29
# Animation     62
# Adventure     75
# Biography     77
# Crime        124
# Action       136
# Comedy       156
# Drama        278
# Name: genre, dtype: int64

# %%
movies.info
# Out:
# <bound method DataFrame.info of                                                    star_rating content_rating  \
# title
# The Shawshank Redemption                                   9.3              R
# The Godfather                                              9.2              R
# The Godfather: Part II                                     9.1              R
# The Dark Knight                                            9.0          PG-13
# Pulp Fiction                                               8.9              R
# 12 Angry Men                                               8.9      NOT RATED
# The Good, the Bad and the Ugly                             8.9      NOT RATED
# The Lord of the Rings: The Return of the King              8.9          PG-13
# Schindler's List                                           8.9              R
# Fight Club                                                 8.9              R
# ...

# %%
sorted(movies.star_rating.unique())
# Out:
# [7.4000000000000004,
#  7.5,
#  7.5999999999999996,
#  7.7000000000000002,
#  7.7999999999999998,
#  7.9000000000000004,
#  8.0,
#  8.0999999999999996,
#  8.1999999999999993,
#  8.3000000000000007,
#  8.4000000000000004,
#  8.5,
#  8.5999999999999996,
#  8.6999999999999993,
#  8.8000000000000007,
#  8.9000000000000004,
#  9.0,
#  9.0999999999999996,
#  9.1999999999999993,
#  9.3000000000000007]

# %%
movies.sort_values('star_rating')
# Out:
#                                                    star_rating content_rating  \
# title
# Wall Street                                                7.4              R
# Bound                                                      7.4              R
# Home Alone                                                 7.4             PG
# Frances Ha                                                 7.4              R
# Eraserhead                                                 7.4        UNRATED
# Far from Heaven                                            7.4          PG-13
# Take Shelter                                               7.4              R
# Terms of Endearment                                        7.4              R
# The Bucket List                                            7.4          PG-13
# Raising Arizona                                            7.4          PG-13
# A Bridge Too Far                                           7.4             PG
# ...
